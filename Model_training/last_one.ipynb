# %%
# All the packages and paths
import pytesseract
import cv2
from object_detection.utils import ops as utils_ops
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
import peakutils
import Levenshtein
import pickle

from distutils.version import StrictVersion
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

from utils import label_map_util
from utils import visualization_utils as vis_util

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import pandas as pd

import statistics as stats
# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'



# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = "C:/tensorflow1/models/research/object_detection/inference_graph/frozen_inference_graph.pb"

path_to_vid = "C:/tensorflow1/models/research/object_detection/own_testing/test3.mp4"

## Load a (frozen) Tensorflow model into memory.

detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

## Loading label map

# Instead of saving it as JSON earlier, I now retyped it manually as a dictionary - not smart, but works.
category_index = {1:  {'id': 1,  'name': 'app'}, 2: {'id': 2,  'name': 'activity'}, 3: {'id': 3,  'name': 'not_over'}, 4:
                  {'id': 4,  'name': 'not_app'}, 5: {'id': 5,  'name': 'pick_over'}, 6: {'id': 6,  'name': 'pick_app'},
                  7: {'id': 7,  'name': 'use_over'}, 8: {'id': 8,  'name': 'week'}}

# Object Detection Functions

# A function that outputs the boxes and
# all the auxiliary data for a single image
def detect_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict

# The same, just processing all images
## in one TF session
def detect_multiple_images(images, graph):
    with graph.as_default():
        with tf.Session() as sess:
            output_dicts = []
            for index, image in enumerate(images):
                ops = tf.get_default_graph().get_operations()
                all_tensor_names = {
                    output.name for op in ops for output in op.outputs}
                tensor_dict = {}
                for key in ['num_detections', 'detection_boxes', 'detection_scores',
                            'detection_classes', 'detection_masks']:
                    tensor_name = key + ':0'
                    if tensor_name in all_tensor_names:
                        tensor_dict[key] = tf.get_default_graph(
                        ).get_tensor_by_name(tensor_name)
                if 'detection_masks' in tensor_dict:
                    # The following processing is only for single image
                    detection_boxes = tf.squeeze(
                        tensor_dict['detection_boxes'], [0])
                    detection_masks = tf.squeeze(
                        tensor_dict['detection_masks'], [0])
                    # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                    real_num_detection = tf.cast(
                        tensor_dict['num_detections'][0], tf.int32)
                    detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                               real_num_detection, -1])
                    detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                               real_num_detection, -1, -1])
                    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                        detection_masks, detection_boxes, image.shape[0], image.shape[1])
                    detection_masks_reframed = tf.cast(
                        tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                    # Follow the convention by adding back the batch dimension
                    tensor_dict['detection_masks'] = tf.expand_dims(
                        detection_masks_reframed, 0)
                image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

                # Run inference
                output_dict = sess.run(tensor_dict,
                                       feed_dict={image_tensor: np.expand_dims(image, 0)})

                # all outputs are float32 numpy arrays, so convert types as appropriate
                output_dict['num_detections'] = int(
                    output_dict['num_detections'][0])
                output_dict['detection_classes'] = output_dict[
                    'detection_classes'][0].astype(np.uint8)
                output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
                output_dict['detection_scores'] = output_dict['detection_scores'][0]
                if 'detection_masks' in output_dict:
                    output_dict['detection_masks'] = output_dict['detection_masks'][0]
                output_dicts.append(output_dict)
    return output_dicts

# getting absolute box coordinates from the relative ones (output of running an inference graph),
# only keeping boxes that detected a field with certainty,
# returns a list with [(coordinates), probability, label type]
def get_abs_coord(image_np, output_dict, thresh):
    coordinates = vis_util.return_coordinates(
        image_np,
        np.squeeze(output_dict['detection_boxes']),
        np.squeeze(output_dict['detection_classes']).astype(np.int32),
        np.squeeze(output_dict['detection_scores']),
        category_index,
        use_normalized_coordinates=True,
        line_thickness=8,
        skip_labels=False,
        min_score_thresh=thresh)
    return coordinates

# Reading the frames

# Helper functions for key frame detection
def scale(img, xScale, yScale):
    res = cv2.resize(img, None, fx=xScale, fy=yScale,
                     interpolation=cv2.INTER_AREA)
    return res

def convert_frame_to_grayscale(frame):
    grayframe = None
    gray = None
    if frame is not None:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        gray = scale(gray, 1, 1)
        grayframe = scale(gray, 1, 1)
        gray = cv2.GaussianBlur(gray, (9, 9), 0.0)
    return grayframe, gray

# A function to load a video into numpy arrays by frame, with the possibility to skip n frames.
# Below a more sophisticated version is included, too
def vid_to_np(path, frame_skip):
    cap = cv2.VideoCapture(path)
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    all_vids = []
    count = 0
    skipper = frame_skip
    while cap.isOpened():
        ret, frame = cap.read()
        if count < (length - skipper):
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            all_vids.append(frame)
            count += skipper
            cap.set(1, count)
        else:
            cap.release()
            break
    return all_vids

# Thres stands for threshold - how dissimilar do the frames have to be included?
# Possible values range: 0 - 1
def keyframeDetection(source):

    # Open the video
    cap = cv2.VideoCapture(source)
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = length/fps

    if (cap.isOpened() == False):
        print("Error opening video file")

    # Empty lists that will be populated
    lstfrm = []
    lstdiffMag = []
    images = []
    full_color = []
    lastFrame = None

    # Read until video is completed
    for i in range(1, length):
        ret, frame = cap.read()
        if ret:
            # Grayscale
            grayframe, blur_gray = convert_frame_to_grayscale(frame)
            # Keeping count of frames to keep comparing to the last one
            frame_number = cap.get(cv2.CAP_PROP_POS_FRAMES) - 1
            lstfrm.append(frame_number)
            images.append(grayframe)
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            rgb_frame = cv2.resize(rgb_frame,None,fx=0.9,fy=0.9)
            full_color.append(rgb_frame)
            if frame_number == 0:
                lastFrame = blur_gray
            # Calculate the difference between two frames
            diff = cv2.subtract(blur_gray, lastFrame)
            diffMag = cv2.countNonZero(diff)
            lstdiffMag.append(diffMag)
            # Current frame becomes last frame
            lastFrame = blur_gray
        else:
            break

    cap.release()
    y = np.array(lstdiffMag)
    min_dur =  int(2*duration)
    # A neat function to index the frames the difference between which meets the threshold
    # Props to Stack Overflow for this
    # To like 70% of the whole code, matter of fact
    base = peakutils.baseline(y, 2)
    the_index = []
    for thr in np.arange(0.56, 0.07, -0.015):
        indices = peakutils.indexes(y-base, round(thr, 2), min_dist=1)
        if len(indices) > min_dur:
            print(min_dur)
            print("threshold of {}".format(thr))
            the_index = indices
            break
    

    final = []
    for x in the_index:
        final.append(full_color[x])

    cv2.destroyAllWindows()
    return(final)

# Takes an app image and returns a dataframe with the detected words
# Trail determines how much to cut off from the right side
def app_to_text(img, leftSide, blurry, trail, v_type):
    height, width, channels = img.shape
    if ph1 < 120:
        img = cv2.bitwise_not(img)
    # resizing if the image if too small
    img = cv2.resize(img, (int(width*(150/height)), 150),
                     interpolation=cv2.INTER_LANCZOS4)
    # pre-processing for better OCR
    # here, it's cropped to remove the app logo
    # also, we can remove the overall time with 'trail' (~150px), or set it to 0 if needed
    img = img[0:150, leftSide:(int(width*(150/height))-trail)]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = cv2.medianBlur(img, blurry)
    if v_type == "weekly":
        img = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
                    cv2.THRESH_BINARY,19,9)
        img = cv2.medianBlur(img, 5)
    else: 
        ret, img = cv2.threshold(img, black_point, 255, cv2.THRESH_BINARY)
    ## texter = pytesseract.image_to_string(img)
    datum = pytesseract.image_to_data(
        img, output_type=pytesseract.Output.DATAFRAME)

    #img = cv2.medianBlur(img,3)
    return datum

# A function that takes the image with 'activity' (time)
## and transforms that into text (string)
def activ_to_text(img):
    height, width, channels = img.shape
    if ph1 < 120:
        img = cv2.bitwise_not(img)
    # resizing if the image is too small
    img = cv2.resize(img, (int(width*(150/height)), 150),
                     interpolation=cv2.INTER_LANCZOS4)
    # pre-processing for better OCR
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = cv2.medianBlur(img, 3)
    ret, img = cv2.threshold(img, black_point, 255, cv2.THRESH_BINARY)
    # detecting the text
    texter = pytesseract.image_to_string(img)
    for rep in replacements:
        # replacing the common mistakes
        texter = texter.replace(rep[0], rep[1])
    return texter

# processing notification and phone pick up apps
def process_week_app(images):
    week_apps = []
    for image in images:
        s = app_to_text(image,130, 3, 0, video_type)
        s = s.dropna()

        if len(s) < 2:
            continue
        
        week_app = []
        app_name = []
        app_name_conf = []
        app_time = []

        for index, row in s.iterrows():
            # for the name, it's the first block and line
            if row["block_num"] == 1 and row["line_num"] == 1:
                app_name.append(row["text"])
                # Also getting OCR confidence for the name
                app_name_conf.append(row["conf"])
        # If there's nothing, go to the next one        
        if len(app_name) == 0:
            continue
            
        app_name_conf = stats.mean(app_name_conf)
        # If unsure, go to the next onew
        if app_name_conf < 90:
            continue
        if s.iloc[-1, -2] < 60:
            continue

        app_name = " ".join(app_name)
        # Getting the number from the last row of the df
        app_time = s.iloc[-1, -1]
        week_app = [app_name, app_time]
        if len(week_apps) == 0:
            week_apps.append(week_app)
        else:
            counter = 0
            for ii in week_apps:
                # check if the app is already in the list
                if fuzz.ratio(app_name, ii[0]) > 75:
                    counter += 1
                    break
            if counter == 0:
                week_apps.append(week_app)
            else:
                continue
    return week_apps

# Takes the dataframe, outputs the app name and the app times
# Importanly, also includes recognitino confidence for the name
# Output: [(name, conf), [time, time2 if exists]]
def process_app(app_img):
    # We get a pandas dataframe
    s = app_to_text(app_img, 90, 5, 150, video_type)
    s = s.dropna()

    app_name = []
    app_name_conf = []
    app_time = []
    # Iterate over the rows of the df, to get the name and the time
    for index, row in s.iterrows():
        # for the name, it's the first block and line
        if row["block_num"] == 1 and row["line_num"] == 1:
            app_name.append(row["text"])
            # Also getting OCR confidence for the name
            app_name_conf.append(row["conf"])
        else:
            # Everything else is time by exclusion
            # Fixing commong digit recognition mistakes,
            # so only taking words that are probably time-indicators
            if len(row["text"]) < 4:
                temp_app = ""
                for rep in digit_repl:
                    temp_app = row["text"].replace(rep[0], rep[1])
                app_time.append(temp_app)
            else:
                app_time.append(row["text"])
    if len(app_name_conf) == 0:
        return [("", 0), 0]

    app_name_conf = stats.mean(app_name_conf)
    app_name = " ".join(app_name)
    app_time = " ".join(app_time)

    for rep in app_replacements:
        # Replacing the common mistakes
        app_time = app_time.replace(rep[0], rep[1])
    # Splitting the on-screen and bg times
    app_time = app_time.split("-")
    app_tuple = (app_name, app_name_conf)
    return [app_tuple, app_time]

# Only keeps the unique and healthy apps per list (hour)
def apps_this_hour(hour):
    this_hour = []
    # start counting from the second element, since the first is 'activity'
    for i in range(1, len(hour)):
        app = process_app(hour[i][1])
        # Only consider apps with confidence above 90
        if app[0][1] < 90:
            continue
        # If the name is empty, or if something is wrong with the times, skip
        elif len(app[0][0].strip()) == 0 or len(app[1][0]) > 13:
            continue
        else:
            # append the app if it's the first one
            if len(this_hour) == 0:
                this_hour.append(app)
                continue
            counter = 1
            for ii in this_hour:
                # check if the app is already in the list
                if fuzz.ratio(app[0][0], ii[0][0]) > 75:
                    counter = 0
                    break
            # if it is not, append it
            if counter > 0:
                this_hour.append(app)
    return this_hour

# Using the extracted key frames and the coordinates of the bounding boxes
# Format is: first layer - hours
# second layer: first element is time, all subsequent - apps
# third layer: first element is the label, second - app image
# output[i][0][1] - time; output[i][1:ii][1] - app image
def photos_to_dicts(photos, coordinates):
    sorted_dicts = []
    # take each screen and the respective box coordinates
    for i, photo in enumerate(photos):
        for part in coordinates[i]:
            # if the box coordinate is 'activity', create a new list
            if part[5] == 2:
                img = photo[part[0]:part[1], part[2]:part[3]]
                # get the text from the image
                texter = activ_to_text(img)
                # check if it looks like it should
                ##print(texter)
                var1 = fuzz.ratio(texter, "ACTIVITY (00:00-00:00)")
                var2 = fuzz.ratio(texter, "ACTIVITY BY APP (00:00-00:00)")
                sim_score = max([var1, var2])
                if sim_score > 80 and len(texter) in [22,29]:
                    # append immediately if it's the first time 'activity' is encountered
                    if len(sorted_dicts) == 0:
                        sorted_dicts.append([[part[5], texter]])
                        ##print("first time hour shown")
                        continue
                    # append a new one if it's a new hour
                    if fuzz.ratio(texter, sorted_dicts[-1][0][1]) < 99:
                        sorted_dicts.append([[part[5], texter]])
                        ##print("new hour")
            # if the box coordinate is 'app', append it to the latest 'activity'
            if part[5] == 1:
                if len(sorted_dicts) > 0:
                    img = photo[part[0]:part[1], part[2]:part[3]]
                    sorted_dicts[-1].append([part[5], img])
    return sorted_dicts

def write_logger(x):
    outF = open("logger_file.txt", "w")
    # write line to output file
    xx = str(x)
    outF.writelines(xx)
    outF.close()
# Out:
# C:\Users\User\Miniconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\User\Miniconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\User\Miniconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\User\Miniconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\User\Miniconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\User\Miniconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
keyframeDetection("D:/SinSu/all_videos/Digital_Sleep_Lab_01-19-2020_2_Battery section video_6646645211529216.mp4")
# Out:
# 413
# threshold of 0.19999999999999973
# [array([[[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24]],
#
#         [[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24]],
#
#         [[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24]],
#
#         ...,
#
#         [[26, 38, 41],
#          [26, 38, 41],
#          [26, 38, 41],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[26, 38, 41],
#          [26, 38, 41],
#          [26, 38, 41],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[26, 38, 41],
#          [26, 38, 41],
#          [26, 38, 41],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24]],
#
#         [[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24]],
#
#         [[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [23, 20, 23],
#          [23, 20, 23],
#          [23, 20, 23]],
#
#         [[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [23, 20, 23],
#          [23, 20, 23],
#          [23, 20, 23]],
#
#         [[25, 22, 27],
#          [25, 22, 27],
#          [25, 22, 27],
#          ...,
#          [23, 20, 23],
#          [23, 20, 23],
#          [23, 20, 23]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24],
#          ...,
#          [21, 18, 21],
#          [21, 18, 21],
#          [21, 18, 21]],
#
#         [[24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24],
#          ...,
#          [21, 18, 21],
#          [21, 18, 21],
#          [21, 18, 21]],
#
#         [[24, 21, 24],
#          [24, 21, 24],
#          [24, 21, 24],
#          ...,
#          [21, 18, 21],
#          [21, 18, 21],
#          [21, 18, 21]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[25, 22, 25],
#          [25, 22, 25],
#          [25, 22, 25],
#          ...,
#          [22, 19, 22],
#          [22, 19, 22],
#          [22, 19, 22]],
#
#         [[25, 22, 25],
#          [25, 22, 25],
#          [25, 22, 25],
#          ...,
#          [22, 19, 22],
#          [22, 19, 22],
#          [22, 19, 22]],
#
#         [[25, 22, 25],
#          [25, 22, 25],
#          [25, 22, 25],
#          ...,
#          [22, 19, 22],
#          [22, 19, 22],
#          [22, 19, 22]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[25, 22, 25],
#          [25, 22, 25],
#          [25, 22, 25],
#          ...,
#          [22, 19, 22],
#          [22, 19, 22],
#          [22, 19, 22]],
#
#         [[25, 22, 25],
#          [25, 22, 25],
#          [25, 22, 25],
#          ...,
#          [22, 19, 22],
#          [22, 19, 22],
#          [22, 19, 22]],
#
#         [[25, 22, 25],
#          [25, 22, 25],
#          [25, 22, 25],
#          ...,
#          [22, 19, 22],
#          [22, 19, 22],
#          [22, 19, 22]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27],
#          ...,
#          [27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27]],
#
#         [[27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27],
#          ...,
#          [27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27]],
#
#         [[27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27],
#          ...,
#          [27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[31, 28, 31],
#          [31, 28, 31],
#          [31, 28, 31],
#          ...,
#          [30, 27, 30],
#          [30, 27, 30],
#          [30, 27, 30]],
#
#         [[31, 28, 31],
#          [31, 28, 31],
#          [31, 28, 31],
#          ...,
#          [30, 27, 30],
#          [30, 27, 30],
#          [30, 27, 30]],
#
#         [[31, 28, 31],
#          [31, 28, 31],
#          [31, 28, 31],
#          ...,
#          [30, 27, 30],
#          [30, 27, 30],
#          [30, 27, 30]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 33, 36],
#          [36, 33, 36],
#          [36, 33, 36],
#          ...,
#          [34, 31, 34],
#          [35, 32, 35],
#          [35, 32, 35]],
#
#         [[36, 33, 36],
#          [36, 33, 36],
#          [36, 33, 36],
#          ...,
#          [34, 31, 34],
#          [35, 32, 35],
#          [35, 32, 35]],
#
#         [[36, 33, 36],
#          [36, 33, 36],
#          [36, 33, 36],
#          ...,
#          [34, 31, 34],
#          [35, 32, 35],
#          [35, 32, 35]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [35, 32, 35],
#          [36, 33, 36],
#          [36, 33, 36]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [35, 32, 35],
#          [36, 33, 36],
#          [36, 33, 36]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [35, 32, 35],
#          [36, 33, 36],
#          [36, 33, 36]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[35, 32, 35],
#          [35, 32, 35],
#          [35, 32, 35],
#          ...,
#          [34, 31, 34],
#          [34, 31, 34],
#          [34, 31, 34]],
#
#         [[35, 32, 35],
#          [35, 32, 35],
#          [35, 32, 35],
#          ...,
#          [34, 31, 34],
#          [34, 31, 34],
#          [34, 31, 34]],
#
#         [[35, 32, 35],
#          [35, 32, 35],
#          [35, 32, 35],
#          ...,
#          [34, 31, 34],
#          [34, 31, 34],
#          [34, 31, 34]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [27, 24, 29],
#          [27, 24, 29],
#          [27, 24, 29]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [38, 35, 40],
#          [38, 35, 40],
#          [38, 35, 40]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27],
#          ...,
#          [27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27]],
#
#         [[27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27],
#          ...,
#          [27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27]],
#
#         [[27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27],
#          ...,
#          [27, 24, 27],
#          [27, 24, 27],
#          [27, 24, 27]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[32, 29, 32],
#          [32, 29, 32],
#          [32, 29, 32],
#          ...,
#          [31, 28, 31],
#          [31, 28, 31],
#          [31, 28, 31]],
#
#         [[32, 29, 32],
#          [32, 29, 32],
#          [32, 29, 32],
#          ...,
#          [31, 28, 31],
#          [31, 28, 31],
#          [31, 28, 31]],
#
#         [[32, 29, 32],
#          [32, 29, 32],
#          [32, 29, 32],
#          ...,
#          [31, 28, 31],
#          [31, 28, 31],
#          [31, 28, 31]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 42, 41],
#          [38, 42, 41],
#          [38, 42, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 42, 41],
#          [38, 42, 41],
#          [38, 42, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 42, 41],
#          [38, 42, 41],
#          [38, 42, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 51, 40],
#          [37, 52, 41],
#          [37, 52, 41],
#          ...,
#          [38, 37, 39],
#          [38, 37, 39],
#          [38, 37, 39]],
#
#         [[36, 51, 40],
#          [37, 52, 41],
#          [37, 52, 41],
#          ...,
#          [38, 37, 39],
#          [38, 37, 39],
#          [38, 37, 39]],
#
#         [[36, 51, 40],
#          [37, 52, 41],
#          [37, 52, 41],
#          ...,
#          [38, 37, 39],
#          [38, 37, 39],
#          [38, 37, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 37, 44],
#          [37, 37, 44],
#          [37, 37, 44],
#          ...,
#          [38, 37, 39],
#          [38, 37, 39],
#          [38, 37, 39]],
#
#         [[37, 37, 44],
#          [37, 37, 44],
#          [37, 37, 44],
#          ...,
#          [38, 37, 39],
#          [38, 37, 39],
#          [38, 37, 39]],
#
#         [[37, 37, 44],
#          [37, 37, 44],
#          [37, 37, 44],
#          ...,
#          [38, 37, 39],
#          [38, 37, 39],
#          [38, 37, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[39, 38, 42],
#          [39, 38, 42],
#          [39, 38, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 38, 42],
#          [39, 38, 42],
#          [39, 38, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 38, 42],
#          [39, 38, 42],
#          [39, 38, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [35, 36, 40],
#          [35, 36, 40],
#          [35, 36, 40]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [35, 36, 40],
#          [35, 36, 40],
#          [35, 36, 40]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [35, 36, 40],
#          [35, 36, 40],
#          [35, 36, 40]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[40, 38, 39],
#          [40, 38, 39],
#          [40, 38, 39],
#          ...,
#          [36, 36, 43],
#          [36, 36, 43],
#          [36, 36, 43]],
#
#         [[40, 38, 39],
#          [40, 38, 39],
#          [40, 38, 39],
#          ...,
#          [36, 36, 43],
#          [36, 36, 43],
#          [36, 36, 43]],
#
#         [[40, 38, 39],
#          [40, 38, 39],
#          [40, 38, 39],
#          ...,
#          [36, 36, 43],
#          [36, 36, 43],
#          [36, 36, 43]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[39, 37, 36],
#          [39, 37, 36],
#          [39, 37, 36],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 37, 36],
#          [39, 37, 36],
#          [39, 37, 36],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 37, 36],
#          [39, 37, 36],
#          [39, 37, 36],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [33, 31, 36],
#          [33, 31, 36],
#          [33, 31, 36]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[47, 45, 32],
#          [47, 45, 32],
#          [47, 45, 32],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[47, 45, 31],
#          [47, 45, 31],
#          [47, 45, 31],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[47, 45, 30],
#          [47, 45, 30],
#          [47, 45, 30],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[33, 44, 47],
#          [33, 44, 47],
#          [33, 44, 47],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[33, 44, 47],
#          [33, 44, 47],
#          [33, 44, 47],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[33, 44, 47],
#          [33, 44, 47],
#          [33, 44, 47],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[35, 41, 46],
#          [35, 41, 46],
#          [35, 41, 46],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[35, 41, 46],
#          [35, 41, 46],
#          [35, 41, 46],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 41, 46],
#          [36, 41, 46],
#          [36, 41, 46],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[40, 35, 41],
#          [40, 35, 41],
#          [40, 35, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[40, 35, 41],
#          [40, 35, 41],
#          [40, 35, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[40, 35, 41],
#          [40, 35, 41],
#          [40, 35, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[47, 38, 45],
#          [47, 38, 45],
#          [47, 38, 45],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[47, 38, 45],
#          [47, 38, 45],
#          [47, 38, 45],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[47, 38, 45],
#          [47, 38, 45],
#          [47, 38, 45],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[54, 40, 49],
#          [54, 40, 49],
#          [54, 40, 49],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[54, 40, 49],
#          [54, 40, 49],
#          [54, 40, 49],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[54, 40, 49],
#          [54, 40, 49],
#          [54, 40, 49],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[48, 41, 42],
#          [48, 41, 42],
#          [48, 41, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[48, 41, 42],
#          [48, 41, 42],
#          [48, 41, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[48, 41, 42],
#          [48, 41, 42],
#          [48, 41, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[47, 42, 46],
#          [47, 42, 46],
#          [47, 42, 46],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[47, 42, 46],
#          [47, 42, 46],
#          [47, 42, 46],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[47, 42, 46],
#          [47, 42, 46],
#          [47, 42, 46],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[40, 35, 39],
#          [40, 35, 39],
#          [40, 35, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[40, 35, 39],
#          [40, 35, 39],
#          [40, 35, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[40, 35, 39],
#          [40, 35, 39],
#          [40, 35, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[51, 40, 44],
#          [51, 40, 44],
#          [51, 40, 44],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[51, 40, 44],
#          [51, 40, 44],
#          [51, 40, 44],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[51, 40, 44],
#          [51, 40, 44],
#          [51, 40, 44],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[35, 45, 62],
#          [35, 45, 62],
#          [35, 45, 62],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[35, 45, 63],
#          [35, 45, 63],
#          [35, 45, 63],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[35, 45, 64],
#          [35, 45, 64],
#          [35, 45, 64],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[34, 44, 61],
#          [34, 44, 61],
#          [34, 44, 61],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[34, 44, 61],
#          [34, 44, 61],
#          [34, 44, 61],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[34, 44, 61],
#          [34, 44, 61],
#          [34, 44, 61],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 40, 39],
#          [36, 40, 39],
#          [36, 40, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 40, 39],
#          [36, 40, 39],
#          [36, 40, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 40, 39],
#          [36, 40, 39],
#          [36, 40, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[39, 38, 42],
#          [39, 38, 42],
#          [39, 38, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 38, 42],
#          [39, 38, 42],
#          [39, 38, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 38, 42],
#          [39, 38, 42],
#          [39, 38, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          ...,
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1]],
#
#         [[ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          ...,
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1]],
#
#         [[ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          ...,
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1]]], dtype=uint8), array([[[42, 47, 55],
#          [42, 47, 55],
#          [42, 47, 55],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[43, 48, 56],
#          [43, 48, 56],
#          [43, 48, 56],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[43, 48, 56],
#          [43, 48, 56],
#          [43, 48, 56],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          ...,
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1]],
#
#         [[ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          ...,
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1]],
#
#         [[ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          ...,
#          [ 1,  0,  1],
#          [ 1,  0,  1],
#          [ 1,  0,  1]]], dtype=uint8), array([[[38, 39, 43],
#          [38, 39, 43],
#          [38, 39, 43],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 39, 43],
#          [38, 39, 43],
#          [38, 39, 43],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 39, 43],
#          [38, 39, 43],
#          [38, 39, 43],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[41, 40, 42],
#          [41, 40, 42],
#          [41, 40, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[41, 40, 42],
#          [41, 40, 42],
#          [41, 40, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[41, 40, 42],
#          [41, 40, 42],
#          [41, 40, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[46, 48, 56],
#          [46, 48, 56],
#          [46, 48, 56],
#          ...,
#          [38, 35, 38],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[46, 48, 56],
#          [46, 48, 56],
#          [46, 48, 56],
#          ...,
#          [38, 35, 38],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[46, 48, 56],
#          [46, 48, 56],
#          [46, 48, 56],
#          ...,
#          [38, 35, 38],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 37, 41],
#          [38, 37, 41],
#          [38, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 37, 41],
#          [38, 37, 41],
#          [38, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 37, 41],
#          [38, 37, 41],
#          [38, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 48, 59],
#          [37, 48, 59],
#          [37, 48, 59],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 48, 59],
#          [37, 48, 59],
#          [37, 48, 59],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 48, 59],
#          [37, 48, 59],
#          [37, 48, 59],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[45, 47, 47],
#          [45, 47, 47],
#          [45, 47, 47],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[45, 47, 47],
#          [45, 47, 47],
#          [45, 47, 47],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[45, 47, 47],
#          [45, 47, 47],
#          [45, 47, 47],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[39, 40, 52],
#          [39, 40, 52],
#          [39, 40, 52],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 40, 52],
#          [39, 40, 52],
#          [39, 40, 52],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[39, 40, 52],
#          [39, 40, 52],
#          [39, 40, 52],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[35, 45, 56],
#          [35, 45, 56],
#          [35, 45, 56],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[35, 45, 56],
#          [35, 45, 56],
#          [35, 45, 56],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[35, 45, 56],
#          [35, 45, 56],
#          [35, 45, 56],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[35, 41, 43],
#          [35, 41, 43],
#          [35, 41, 43],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[35, 41, 43],
#          [35, 41, 43],
#          [35, 41, 43],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[35, 41, 43],
#          [35, 41, 43],
#          [35, 41, 43],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[35, 36, 40],
#          [35, 36, 40],
#          [35, 36, 40],
#          ...,
#          [38, 35, 38],
# ...
#          [39, 36, 39]],
#
#         [[36, 39, 42],
#          [36, 39, 42],
#          [36, 39, 42],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 55, 40],
#          [37, 55, 40],
#          [37, 55, 40],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[37, 55, 40],
#          [37, 55, 40],
#          [37, 55, 40],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[37, 55, 40],
#          [37, 55, 40],
#          [37, 55, 40],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 46, 63],
#          [36, 46, 63],
#          [36, 46, 63],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[36, 46, 63],
#          [36, 46, 63],
#          [36, 46, 63],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[36, 46, 63],
#          [36, 46, 63],
#          [36, 46, 63],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[37, 36, 38],
#          [37, 36, 38],
#          [37, 36, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[52, 45, 46],
#          [52, 45, 46],
#          [52, 45, 46],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[52, 45, 46],
#          [52, 45, 46],
#          [52, 45, 46],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         [[52, 45, 46],
#          [52, 45, 46],
#          [52, 45, 46],
#          ...,
#          [39, 36, 39],
#          [39, 36, 39],
#          [39, 36, 39]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[40, 35, 39],
#          [40, 35, 39],
#          [40, 35, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[40, 35, 39],
#          [40, 35, 39],
#          [40, 35, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[40, 35, 39],
#          [40, 35, 39],
#          [40, 35, 39],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[43, 35, 42],
#          [43, 35, 42],
#          [43, 35, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[43, 35, 42],
#          [43, 35, 42],
#          [43, 35, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[43, 35, 42],
#          [43, 35, 42],
#          [43, 35, 42],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 36, 43],
#          [36, 36, 43],
#          [36, 36, 43],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 36, 43],
#          [36, 36, 43],
#          [36, 36, 43],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 36, 43],
#          [36, 36, 43],
#          [36, 36, 43],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         [[36, 37, 41],
#          [36, 37, 41],
#          [36, 37, 41],
#          ...,
#          [38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[33, 53, 38],
#          [33, 53, 38],
#          [33, 53, 38],
#          ...,
#          [38, 37, 39],
#          [37, 36, 38],
#          [37, 36, 38]],
#
#         [[33, 53, 38],
#          [33, 53, 38],
#          [33, 53, 38],
#          ...,
#          [37, 37, 39],
#          [37, 36, 38],
#          [37, 36, 38]],
#
#         [[33, 53, 38],
#          [33, 53, 38],
#          [33, 53, 38],
#          ...,
#          [37, 37, 39],
#          [37, 36, 38],
#          [37, 36, 38]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [41, 38, 41],
#          [41, 38, 41],
#          [41, 38, 41]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [41, 38, 41],
#          [41, 38, 41],
#          [41, 38, 41]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [41, 38, 41],
#          [41, 38, 41],
#          [41, 38, 41]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[34, 31, 34],
#          [34, 31, 34],
#          [34, 31, 34],
#          ...,
#          [33, 30, 33],
#          [33, 30, 33],
#          [33, 30, 33]],
#
#         [[34, 31, 34],
#          [34, 31, 34],
#          [34, 31, 34],
#          ...,
#          [33, 30, 33],
#          [33, 30, 33],
#          [33, 30, 33]],
#
#         [[34, 31, 34],
#          [34, 31, 34],
#          [34, 31, 34],
#          ...,
#          [33, 30, 33],
#          [33, 30, 33],
#          [33, 30, 33]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [42, 39, 42],
#          [42, 39, 42],
#          [42, 39, 42]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [42, 39, 42],
#          [42, 39, 42],
#          [42, 39, 42]],
#
#         [[38, 35, 38],
#          [38, 35, 38],
#          [38, 35, 38],
#          ...,
#          [42, 39, 42],
#          [42, 39, 42],
#          [42, 39, 42]],
#
#         ...,
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]],
#
#         [[28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30],
#          ...,
#          [28, 25, 30],
#          [28, 25, 30],
#          [28, 25, 30]]], dtype=uint8), array([[[41, 38, 41],
#          [41, 38, 41],
#          [41, 38, 41],
#          ...,
#          [40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40]],
#
#         [[41, 38, 41],
#          [41, 38, 41],
#          [41, 38, 41],
#          ...,
#          [40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40]],
#
#         [[41, 38, 41],
#          [41, 38, 41],
#          [41, 38, 41],
#          ...,
#          [40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40]],
#
#         ...,
#
#         [[44, 41, 44],
#          [44, 41, 44],
#          [44, 41, 44],
#          ...,
#          [43, 40, 43],
#          [43, 40, 43],
#          [43, 40, 43]],
#
#         [[44, 41, 44],
#          [44, 41, 44],
#          [44, 41, 44],
#          ...,
#          [43, 40, 43],
#          [43, 40, 43],
#          [43, 40, 43]],
#
#         [[44, 41, 44],
#          [44, 41, 44],
#          [44, 41, 44],
#          ...,
#          [43, 40, 43],
#          [43, 40, 43],
#          [43, 40, 43]]], dtype=uint8), array([[[40, 39, 41],
#          [40, 39, 41],
#          [40, 39, 41],
#          ...,
#          [40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40]],
#
#         [[40, 39, 41],
#          [40, 39, 41],
#          [40, 39, 41],
#          ...,
#          [40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40]],
#
#         [[40, 39, 41],
#          [40, 39, 41],
#          [40, 39, 41],
#          ...,
#          [40, 37, 40],
#          [40, 37, 40],
#          [40, 37, 40]],
#
#         ...,
#
#         [[54, 53, 57],
#          [54, 53, 57],
#          [54, 53, 57],
#          ...,
#          [43, 40, 43],
#          [43, 40, 43],
#          [43, 40, 43]],
#
#         [[54, 53, 57],
#          [54, 53, 57],
#          [54, 53, 57],
#          ...,
#          [43, 40, 43],
#          [43, 40, 43],
#          [43, 40, 43]],
#
#         [[54, 53, 57],
#          [54, 53, 57],
#          [54, 53, 57],
#          ...,
#          [43, 40, 43],
#          [43, 40, 43],
#          [43, 40, 43]]], dtype=uint8)]

# %%
def app_to_text2(img, leftSide, blurry, trail, v_type):
    height, width, channels = img.shape
    if ph1 < 120:
        img = cv2.bitwise_not(img)
    # resizing if the image if too small
    img = cv2.resize(img, (int(width*(150/height)), 150),
                     interpolation=cv2.INTER_LANCZOS4)
    # pre-processing for better OCR
    # here, it's cropped to remove the app logo
    # also, we can remove the overall time with 'trail' (~150px), or set it to 0 if needed
    #img = img[0:150, leftSide:(int(width*(150/height))-trail)]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = cv2.medianBlur(img, blurry)
    if v_type == "weekly":
        img = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
                    cv2.THRESH_BINARY,19,9)
        img = cv2.medianBlur(img, 5)
    else: 
        ret, img = cv2.threshold(img, black_point, 255, cv2.THRESH_BINARY)
    ## texter = pytesseract.image_to_string(img)
    datum = pytesseract.image_to_string(img)

    #img = cv2.medianBlur(img,3)
    return datum

# %%
all_dirs = os.listdir("D:/SinSu/all_videos")
outputs = {}
logger = {}

# %%
file1 = open("last_names.txt", "r") 
done1 = file1.readlines()
done1 = [x[:-1] for x in done1]
file1.close()

# %%
debil = {}

# %%
done1
# Out:
# ['Digital_Sleep_Lab_09-27-2019_4_5820415616745472.mp4',
#  'Digital_Sleep_Lab_09-27-2019_4_5820415616745472.mp4',
#  'Digital_Sleep_Lab_01-22-2020_4_5828672901087232.mp4',
#  'Digital_Sleep_Lab_01-19-2020_4_4957795351265280.mp4',
#  'Digital_Sleep_Lab_09-27-2019_4_5657390939111424.mp4',
#  'Digital_Sleep_Lab_12-05-2019_4_5644090658521088.mp4',
#  'Digital_Sleep_Lab_10-03-2019_4_4568678536839168.mp4',
#  'Digital_Sleep_Lab_09-20-2019_4_5028874283384832.mp4',
#  'Digital_Sleep_Lab_12-02-2019_4_5814793462611968.mp4',
#  'Digital_Sleep_Lab_11-29-2019_4_5625570390441984.mp4',
#  'Digital_Sleep_Lab_11-21-2019_4_5041346893578240.mp4',
#  'Digital_Sleep_Lab_11-17-2019_4_6085186249293824.mp4',
#  'Digital_Sleep_Lab_10-02-2019_4_5924249806569472.mp4',
#  'Digital_Sleep_Lab_10-02-2019_4_5924249806569472.mp4',
#  'Digital_Sleep_Lab_01-24-2020_4_4633809845223424.mp4',
#  'Digital_Sleep_Lab_12-09-2019_4_6517361125883904.mp4',
#  'Digital_Sleep_Lab_12-09-2019_4_5224738239021056.mp4',
#  'Digital_Sleep_Lab_01-27-2020_4_5702815863799808.mp4',
#  'Digital_Sleep_Lab_01-25-2020_4_5855160836816896.mp4',
#  'Digital_Sleep_Lab_11-24-2019_4_5799868350595072.mp4',
#  'Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4',
#  'Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4',
#  'Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4',
#  'Digital_Sleep_Lab_12-11-2019_4_6694086078103552.mp4',
#  'Digital_Sleep_Lab_11-25-2019_4_6388877078560768.mp4',
#  'Digital_Sleep_Lab_11-03-2019_4_6356206378024960.mp4',
#  'Digital_Sleep_Lab_11-03-2019_4_6356206378024960.mp4',
#  'Digital_Sleep_Lab_11-26-2019_4_5883411403636736.mp4',
#  'Digital_Sleep_Lab_11-27-2019_4_5319684161798144.mp4',
#  'Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4',
#  'Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4',
#  'Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4',
#  'Digital_Sleep_Lab_09-23-2019_4_5553477963481088.mp4',
#  'Digital_Sleep_Lab_12-04-2019_4_6343848473657344.mp4',
#  'Digital_Sleep_Lab_11-15-2019_4_4984582424756224.mp4',
#  'Digital_Sleep_Lab_12-10-2019_4_5027542533144576.mp4',
#  'Digital_Sleep_Lab_01-22-2020_4_5050699704958976.mp4',
#  'Digital_Sleep_Lab_01-23-2020_4_5782680680005632.mp4',
#  'Digital_Sleep_Lab_12-02-2019_4_5781757245259776.mp4',
#  'Digital_Sleep_Lab_09-22-2019_4_6402762816880640.mp4',
#  'Digital_Sleep_Lab_11-22-2019_2_Battery section video_5087127956619264.mp4',
#  'Digital_Sleep_Lab_11-29-2019_4_6275219795214336.mp4',
#  'Digital_Sleep_Lab_11-30-2019_4_5019348339523584.mp4',
#  'Digital_Sleep_Lab_11-30-2019_4_5019348339523584.mp4',
#  'Digital_Sleep_Lab_12-06-2019_4_4597500342697984.mp4',
#  'Digital_Sleep_Lab_01-20-2020_4_5308527598370816.mp4',
#  'Digital_Sleep_Lab_11-16-2019_4_5183000652808192.mp4',
#  'Digital_Sleep_Lab_01-29-2020_4_5540104987213824.mp4',
#  'Digital_Sleep_Lab_11-14-2019_4_6209347177152512.mp4',
#  'Digital_Sleep_Lab_11-27-2019_4_6415398937821184.mp4',
#  'Digital_Sleep_Lab_11-18-2019_4_5198243693068288.mp4',
#  'Digital_Sleep_Lab_11-21-2019_4_5254030385741824.mp4',
#  'Digital_Sleep_Lab_09-25-2019_4_6321273999720448.mp4',
#  'Digital_Sleep_Lab_10-13-2019_4_5869933905313792.mp4',
#  'Digital_Sleep_Lab_11-15-2019_4_5785748444282880.mp4',
#  'Digital_Sleep_Lab_12-05-2019_4_5112395450548224.mp4',
#  'Digital_Sleep_Lab_10-04-2019_4_4854233094946816.mp4',
#  'Digital_Sleep_Lab_01-21-2020_4_5849347867017216.mp4',
#  'Digital_Sleep_Lab_01-23-2020_4_5003171596861440.mp4',
#  'Digital_Sleep_Lab_01-18-2020_4_5286841385746432.mp4',
#  'Digital_Sleep_Lab_01-25-2020_4_5310117742903296.mp4',
#  'Digital_Sleep_Lab_11-05-2019_4_6077309077946368.mp4',
#  'Digital_Sleep_Lab_11-05-2019_4_6077309077946368.mp4',
#  'Digital_Sleep_Lab_11-21-2019_4_5786423190355968.mp4',
#  'Digital_Sleep_Lab_12-10-2019_4_6376722354667520.mp4',
#  'Digital_Sleep_Lab_11-28-2019_4_4630350400061440.mp4',
#  'Digital_Sleep_Lab_09-29-2019_4_5175097988481024.mp4',
#  'Digital_Sleep_Lab_12-03-2019_4_5899438342537216.mp4',
#  'Digital_Sleep_Lab_11-30-2019_4_5771441472012288.mp4',
#  'Digital_Sleep_Lab_12-03-2019_4_4943800804311040.mp4',
#  'Digital_Sleep_Lab_12-02-2019_4_5616895126929408.mp4',
#  'Digital_Sleep_Lab_12-09-2019_4_5184539291287552.mp4',
#  'Digital_Sleep_Lab_01-20-2020_4_6107634583732224.mp4',
#  'Digital_Sleep_Lab_12-03-2019_4_6331632680697856.mp4',
#  'Digital_Sleep_Lab_11-28-2019_4_5653674106290176.mp4',
#  'Digital_Sleep_Lab_10-01-2019_4_5224234125623296.mp4',
#  'Digital_Sleep_Lab_12-03-2019_4_6688059098136576.mp4',
#  'Digital_Sleep_Lab_10-13-2019_4_6481110737879040.mp4',
#  'Digital_Sleep_Lab_11-22-2019_4_6426243193372672.mp4',
#  'Digital_Sleep_Lab_11-09-2019_4_5554984750415872.mp4',
#  'Digital_Sleep_Lab_10-06-2019_4_5227228791570432.mp4',
#  'Digital_Sleep_Lab_11-30-2019_4_5244964380868608.mp4',
#  'Digital_Sleep_Lab_09-19-2019_4_6564569099534336.mp4',
#  'Digital_Sleep_Lab_12-03-2019_4_5827146728079360.mp4',
#  'Digital_Sleep_Lab_10-06-2019_4_6400422596575232.mp4',
#  'Digital_Sleep_Lab_09-19-2019_4_5561239304929280.mp4',
#  'Digital_Sleep_Lab_12-09-2019_4_5367900571959296.mp4',
#  'Digital_Sleep_Lab_12-09-2019_4_5367900571959296.mp4',
#  'Digital_Sleep_Lab_12-01-2019_4_6158145160740864.mp4',
#  'Digital_Sleep_Lab_12-01-2019_4_6158145160740864.mp4',
#  'Digital_Sleep_Lab_11-24-2019_4_5907383562272768.mp4',
#  'Digital_Sleep_Lab_11-17-2019_4_5710230369861632.mp4',
#  'Digital_Sleep_Lab_01-21-2020_4_5899530634002432.mp4',
#  'Digital_Sleep_Lab_12-01-2019_4_4637619699318784.mp4',
#  'Digital_Sleep_Lab_09-29-2019_4_5578887157776384.mp4',
#  'Digital_Sleep_Lab_09-29-2019_4_5578887157776384.mp4',
#  'Digital_Sleep_Lab_09-30-2019_4_5878729427910656.mp4',
#  'Digital_Sleep_Lab_09-30-2019_4_5878729427910656.mp4',
#  'Digital_Sleep_Lab_12-13-2019_4_6059879328907264.mp4',
#  'Digital_Sleep_Lab_11-25-2019_4_5236865548943360.mp4']

# %%
for index, direct in enumerate(done1):
    path_to_vid = "D:/SinSu/all_videos/" + direct
    outF = open("logger_file.txt", "r")
    dad = outF.readline()
    dad = int(dad)
    outF.close()
    if index < dad:
        continue
    print("working on video: {}".format(path_to_vid))
    try:
        photos = keyframeDetection(path_to_vid)
    except:
        print("nope")
        logger[index] = "key frame detection error"
        continue
        
    if len(photos) < 15:
        print("too few frames")
        logger[index] = "key frame detection error"
        continue
    
    ph1 = [np.mean(x) for x in photos]
    ph1 = stats.mean(ph1)

    # Based on the brightness, make some adjustments
    if ph1 < 120:
        print("frames nr.: {}".format(len(photos)))
        black_point = 215
        print("dark video")
    else:
        print("frames nr.: {}".format(len(photos)))
        black_point = 228
        print("light video")


    print("detecting items")
    try:
        dicts = detect_multiple_images(photos, detection_graph)
        print("detection successful")
    except:
        print("detection not successful")
        logger[index] = "box detection error"
        continue

    # Now we have bounding boxes, we can get the (coordinates of)
    # the parts of the frame that correspond to them
    # We also keep the label of the box and the confidence level
    
    coordinates = []
    for i, x in enumerate(dicts):
        coord = get_abs_coord(photos[i], x, 0.99)
        coordinates.append(coord)

    # Count the occurences of each label to decide what kind of video it is
    labels = [part[5] for coord in coordinates for part in coord]
    d = {x: labels.count(x) for x in labels}

    if len(d) < 2 or len(labels) < 150:
        print("failed to detect sufficient info, exiting")
        logger[index] = "insufficient boxes error"
        continue

    if 2 not in d or 1 not in d:
        video_type = "weekly"
    elif 3 not in d or 5 not in d:
        video_type = "daily"
    elif 7 not in d:
        video_type = "daily"
    else:
        if (d[1] + d[2]) < (
                d[4] + d[6]):
            video_type = "weekly"
        else:
            video_type = "daily"

    print("type of video: {}".format(video_type))
       
    not_over = []
    pick_over = []
    week_over = []
    for i, photo in enumerate(photos):
            # separate the detected boxes by label
            for part in coordinates[i]:
                if len(not_over) > 0 and len(week_over) > 0 and len(pick_over) > 0:
                    break
                if part[5] == 3:
                    img = photo[part[0]:part[1], part[2]:part[3]]
                    not_over.append(img)
                    cv2.imwrite("last_note/{}.jpg".format(direct), img)
                elif part[5] == 5:
                    img = photo[part[0]:part[1], part[2]:part[3]]
                    cv2.imwrite("last_picks/{}.jpg".format(direct), img)
                    pick_over.append(img)
                elif part[5] == 7:
                    img = photo[part[0]:part[1], part[2]:part[3]]
                    cv2.imwrite("last_weeks/{}.jpg".format(direct), img)
                    week_over.append(img)
                else:
                    continue
    if len(not_over) > 0:
        noter = app_to_text2(not_over[-1], 0, 5, 0, video_type)
    if len(pick_over) > 0:
        picker = app_to_text2(pick_over[-1], 0, 5, 0, video_type)
    if len(week_over) > 0:
        weeker = app_to_text2(week_over[-1], 0, 5, 0, video_type)
    debil[direct] = [noter, picker, weeker]
# Out:
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-27-2019_4_5820415616745472.mp4
# 124
# threshold of 0.53
# frames nr.: 132
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-27-2019_4_5820415616745472.mp4
# 124
# threshold of 0.53
# frames nr.: 132
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-22-2020_4_5828672901087232.mp4
# 118
# threshold of 0.18499999999999972
# frames nr.: 209
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-19-2020_4_4957795351265280.mp4
# 223
# threshold of 0.18499999999999972
# frames nr.: 341
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-27-2019_4_5657390939111424.mp4
# 60
# threshold of 0.3649999999999999
# frames nr.: 61
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-05-2019_4_5644090658521088.mp4
# 98
# threshold of 0.56
# frames nr.: 198
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-03-2019_4_4568678536839168.mp4
# 205
# threshold of 0.19999999999999973
# frames nr.: 250
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-20-2019_4_5028874283384832.mp4
# 134
# threshold of 0.2749999999999998
# frames nr.: 164
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-02-2019_4_5814793462611968.mp4
# 76
# threshold of 0.3949999999999999
# frames nr.: 81
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-29-2019_4_5625570390441984.mp4
# 83
# threshold of 0.56
# frames nr.: 138
# light video
# detecting items
# detection successful
# failed to detect sufficient info, exiting
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-21-2019_4_5041346893578240.mp4
# 104
# threshold of 0.56
# frames nr.: 225
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-17-2019_4_6085186249293824.mp4
# 131
# threshold of 0.545
# frames nr.: 143
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-02-2019_4_5924249806569472.mp4
# 132
# threshold of 0.56
# frames nr.: 168
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-02-2019_4_5924249806569472.mp4
# 132
# threshold of 0.56
# frames nr.: 168
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-24-2020_4_4633809845223424.mp4
# 167
# threshold of 0.1699999999999997
# frames nr.: 215
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-09-2019_4_6517361125883904.mp4
# 78
# threshold of 0.56
# frames nr.: 99
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-09-2019_4_5224738239021056.mp4
# 81
# threshold of 0.56
# frames nr.: 138
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-27-2020_4_5702815863799808.mp4
# 50
# threshold of 0.56
# frames nr.: 141
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-25-2020_4_5855160836816896.mp4
# 56
# threshold of 0.56
# frames nr.: 109
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-24-2019_4_5799868350595072.mp4
# 101
# threshold of 0.34999999999999987
# frames nr.: 107
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4
# 162
# threshold of 0.545
# frames nr.: 165
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4
# 162
# threshold of 0.545
# frames nr.: 165
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4
# 162
# threshold of 0.545
# frames nr.: 165
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-11-2019_4_6694086078103552.mp4
# 86
# threshold of 0.56
# frames nr.: 191
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-25-2019_4_6388877078560768.mp4
# 79
# threshold of 0.56
# frames nr.: 88
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-03-2019_4_6356206378024960.mp4
# 95
# threshold of 0.56
# frames nr.: 156
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-03-2019_4_6356206378024960.mp4
# 95
# threshold of 0.56
# frames nr.: 156
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-26-2019_4_5883411403636736.mp4
# 94
# threshold of 0.3949999999999999
# frames nr.: 100
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-27-2019_4_5319684161798144.mp4
# 127
# threshold of 0.33499999999999985
# frames nr.: 143
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4
# 106
# threshold of 0.53
# frames nr.: 113
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4
# 106
# threshold of 0.53
# frames nr.: 113
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4
# 106
# threshold of 0.53
# frames nr.: 113
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-23-2019_4_5553477963481088.mp4
# 229
# threshold of 0.24499999999999977
# frames nr.: 272
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-04-2019_4_6343848473657344.mp4
# 81
# threshold of 0.42499999999999993
# frames nr.: 82
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-15-2019_4_4984582424756224.mp4
# 135
# threshold of 0.21499999999999975
# frames nr.: 168
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-10-2019_4_5027542533144576.mp4
# 97
# threshold of 0.545
# frames nr.: 104
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-22-2020_4_5050699704958976.mp4
# 127
# threshold of 0.19999999999999973
# frames nr.: 157
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-23-2020_4_5782680680005632.mp4
# 165
# threshold of 0.2899999999999998
# frames nr.: 177
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-02-2019_4_5781757245259776.mp4
# 150
# threshold of 0.3049999999999998
# frames nr.: 167
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-22-2019_4_6402762816880640.mp4
# 193
# threshold of 0.19999999999999973
# frames nr.: 257
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-22-2019_2_Battery section video_5087127956619264.mp4
# 152
# threshold of 0.56
# frames nr.: 304
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-29-2019_4_6275219795214336.mp4
# 69
# threshold of 0.3049999999999998
# frames nr.: 95
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-30-2019_4_5019348339523584.mp4
# 121
# threshold of 0.56
# frames nr.: 426
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-30-2019_4_5019348339523584.mp4
# 121
# threshold of 0.56
# frames nr.: 426
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-06-2019_4_4597500342697984.mp4
# 76
# threshold of 0.34999999999999987
# frames nr.: 79
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-20-2020_4_5308527598370816.mp4
# 293
# threshold of 0.18499999999999972
# frames nr.: 401
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-16-2019_4_5183000652808192.mp4
# 201
# threshold of 0.18499999999999972
# frames nr.: 352
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-29-2020_4_5540104987213824.mp4
# 51
# threshold of 0.2599999999999998
# frames nr.: 64
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-14-2019_4_6209347177152512.mp4
# 133
# threshold of 0.21499999999999975
# frames nr.: 204
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-27-2019_4_6415398937821184.mp4
# 127
# threshold of 0.56
# frames nr.: 208
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-18-2019_4_5198243693068288.mp4
# 75
# threshold of 0.21499999999999975
# frames nr.: 107
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-21-2019_4_5254030385741824.mp4
# 160
# threshold of 0.5
# frames nr.: 191
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-25-2019_4_6321273999720448.mp4
# 94
# threshold of 0.31999999999999984
# frames nr.: 95
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-13-2019_4_5869933905313792.mp4
# 81
# threshold of 0.515
# frames nr.: 86
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-15-2019_4_5785748444282880.mp4
# 209
# threshold of 0.485
# frames nr.: 219
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-05-2019_4_5112395450548224.mp4
# 92
# threshold of 0.22999999999999976
# frames nr.: 103
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-04-2019_4_4854233094946816.mp4
# 164
# threshold of 0.3049999999999998
# frames nr.: 214
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-21-2020_4_5849347867017216.mp4
# 89
# threshold of 0.18499999999999972
# frames nr.: 151
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-23-2020_4_5003171596861440.mp4
# 125
# threshold of 0.18499999999999972
# frames nr.: 142
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-18-2020_4_5286841385746432.mp4
# 191
# threshold of 0.18499999999999972
# frames nr.: 308
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-25-2020_4_5310117742903296.mp4
# 72
# threshold of 0.56
# frames nr.: 201
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-05-2019_4_6077309077946368.mp4
# 202
# threshold of 0.2749999999999998
# frames nr.: 217
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-05-2019_4_6077309077946368.mp4
# 202
# threshold of 0.2749999999999998
# frames nr.: 217
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-21-2019_4_5786423190355968.mp4
# 292
# threshold of 0.18499999999999972
# frames nr.: 391
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-10-2019_4_6376722354667520.mp4
# 190
# threshold of 0.56
# frames nr.: 384
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-28-2019_4_4630350400061440.mp4
# 87
# threshold of 0.56
# frames nr.: 109
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-29-2019_4_5175097988481024.mp4
# 72
# threshold of 0.24499999999999977
# frames nr.: 87
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-03-2019_4_5899438342537216.mp4
# 51
# threshold of 0.56
# frames nr.: 127
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-30-2019_4_5771441472012288.mp4
# 145
# threshold of 0.3049999999999998
# frames nr.: 197
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-03-2019_4_4943800804311040.mp4
# 94
# threshold of 0.42499999999999993
# frames nr.: 104
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-02-2019_4_5616895126929408.mp4
# 34
# threshold of 0.56
# frames nr.: 107
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-09-2019_4_5184539291287552.mp4
# 70
# threshold of 0.21499999999999975
# frames nr.: 78
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-20-2020_4_6107634583732224.mp4
# 91
# threshold of 0.21499999999999975
# frames nr.: 94
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-03-2019_4_6331632680697856.mp4
# 70
# threshold of 0.33499999999999985
# frames nr.: 71
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-28-2019_4_5653674106290176.mp4
# 59
# threshold of 0.56
# frames nr.: 127
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-01-2019_4_5224234125623296.mp4
# 68
# threshold of 0.24499999999999977
# frames nr.: 87
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-03-2019_4_6688059098136576.mp4
# 81
# threshold of 0.56
# frames nr.: 282
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-13-2019_4_6481110737879040.mp4
# 197
# threshold of 0.56
# frames nr.: 306
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-22-2019_4_6426243193372672.mp4
# 160
# threshold of 0.53
# frames nr.: 172
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-09-2019_4_5554984750415872.mp4
# 230
# threshold of 0.56
# frames nr.: 418
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-06-2019_4_5227228791570432.mp4
# 150
# threshold of 0.56
# frames nr.: 238
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-30-2019_4_5244964380868608.mp4
# 101
# threshold of 0.545
# frames nr.: 106
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-19-2019_4_6564569099534336.mp4
# 180
# threshold of 0.21499999999999975
# frames nr.: 203
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-03-2019_4_5827146728079360.mp4
# 84
# threshold of 0.56
# frames nr.: 141
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_10-06-2019_4_6400422596575232.mp4
# 64
# threshold of 0.56
# frames nr.: 151
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-19-2019_4_5561239304929280.mp4
# 126
# threshold of 0.24499999999999977
# frames nr.: 128
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-09-2019_4_5367900571959296.mp4
# 150
# threshold of 0.1549999999999997
# frames nr.: 233
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-09-2019_4_5367900571959296.mp4
# 150
# threshold of 0.1549999999999997
# frames nr.: 233
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-01-2019_4_6158145160740864.mp4
# 94
# threshold of 0.56
# frames nr.: 347
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-01-2019_4_6158145160740864.mp4
# 94
# threshold of 0.56
# frames nr.: 347
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-24-2019_4_5907383562272768.mp4
# 200
# threshold of 0.4099999999999999
# frames nr.: 229
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-17-2019_4_5710230369861632.mp4
# 262
# threshold of 0.19999999999999973
# frames nr.: 264
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_01-21-2020_4_5899530634002432.mp4
# 110
# threshold of 0.19999999999999973
# frames nr.: 142
# dark video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-01-2019_4_4637619699318784.mp4
# 130
# threshold of 0.2899999999999998
# frames nr.: 136
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-29-2019_4_5578887157776384.mp4
# 132
# threshold of 0.545
# frames nr.: 138
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-29-2019_4_5578887157776384.mp4
# 132
# threshold of 0.545
# frames nr.: 138
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-30-2019_4_5878729427910656.mp4
# 116
# threshold of 0.5
# frames nr.: 118
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_09-30-2019_4_5878729427910656.mp4
# 116
# threshold of 0.5
# frames nr.: 118
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_12-13-2019_4_6059879328907264.mp4
# 67
# threshold of 0.56
# frames nr.: 131
# light video
# detecting items
# detection successful
# type of video: weekly
# working on video: D:/SinSu/all_videos/Digital_Sleep_Lab_11-25-2019_4_5236865548943360.mp4
# 104
# threshold of 0.33499999999999985
# frames nr.: 117
# dark video
# detecting items
# detection successful
# type of video: weekly

# %%
pickle.dump( debil, open( "debil.p", "wb" ) )

# %%
import pickle

# %%
debil = pickle.load(open("debil.p", "rb"))

# %%
debil
# Out:
# {'Digital_Sleep_Lab_01-18-2020_4_5286841385746432.mp4': ['ee OO RAD\n\nDaily Average\n\n79°',
#   'Most Pickups Total Pickups\nFriday: 110 462',
#   'Games Social Networking Productivity\nGh 25m ah Sam Sam\n\nTotal Screen Time 16h 32m'],
#  'Digital_Sleep_Lab_01-19-2020_4_4957795351265280.mp4': ['Oal, A.crage\n\n77°',
#   'Most Pickups Total Pickups\nFriday: 110 537',
#   'Werte, DAN Mae lage ere, waaay\n\nTr iGm Sa S6en aim\n\nTotal Screen Tune 1h Sn'],
#  'Digital_Sleep_Lab_01-20-2020_4_5308527598370816.mp4': ['MOT RIZATIONS\n\nDaily Average\nno? -',
#   'Most Pickups Total Pickups\nTuesday: 70 70',
#   '2 on 154 12m\n\nTotal Screen Time 1h 17m'],
#  'Digital_Sleep_Lab_01-20-2020_4_6107634583732224.mp4': ['tte tat one\n\nQa, Alora se\n\n5°',
#   'Most Pickups Total Pickups\nTuesday: 10 10',
#   'Producivity Socal Networking — Catertainment\n3m Im 18s\n\nTotal Screen Time 10m'],
#  'Digital_Sleep_Lab_01-21-2020_4_5849347867017216.mp4': ['',
#   'Most Pickups Total Pickups\nTuesday: 197 221',
#   'SOLO Met aes Satertw rent Craateety\njn am in 39m\n\nTotal Screen Time Ch 40m'],
#  'Digital_Sleep_Lab_01-21-2020_4_5899530634002432.mp4': ['ote cateces,\n\nOuty Average\n\n39°',
#   'Most Pickups Total Pickups\nTuesday: 116 124',
#   'Garies Social Neiworaing Productivity\n32m 26m 18in\n\nTotal Screen Time 2h 7m'],
#  'Digital_Sleep_Lab_01-22-2020_4_5050699704958976.mp4': ['1" 6 Cat,\n\nDaily Average\n\nR1°',
#   'Most Pickups Total Pickups\nTuesday: 197 365',
#   'Somea Teeth eg Ceatesty tete ta wrest\n\nDoin mim 1n 26"\n\nwe\n7\nwa\n3\n\nTota! Screen Tene ‘'],
#  'Digital_Sleep_Lab_01-22-2020_4_5828672901087232.mp4': ['HOT? Cat OS\n\nOvly Act age\n\n49°',
#   'Most Pickups Total Pickups\nTuesday: 116 219',
#   'Gores Socal Networury *OdLCunty\n1m 10m 1h 10m 31m\n\nTotal Sereen Time én 7m'],
#  'Digital_Sleep_Lab_01-23-2020_4_5003171596861440.mp4': ['',
#   'Most Pickups Total Pickups\nTuesday: 197 528',
#   'TN ee eee te wma ey Ae me we\n\nSom 7h thm in Jj\n\nToral Screen Tene VN 64'],
#  'Digital_Sleep_Lab_01-23-2020_4_5782680680005632.mp4': ['tedte Caters\n\nDaty Areage\n\n206°',
#   'Most Pickups Total Pickups\nThursday: 163 562',
#   'Sequibictaowbeg  Createniy Readoy & Relerenwce\n17h £9 2n 16m th $m\n\nTotal Screen Time 25h 33m'],
#  'Digital_Sleep_Lab_01-24-2020_4_4633809845223424.mp4': ['rete lat red\n\nOoty Ace ge\n\n94°',
#   'Most Pickups Total Pickups\nTuesday: 197 648',
#   'mia then ag Cre atety pele ta werent\nVIN oom 7 16 Msn\n\nTot Screen Tene 20n 46'],
#  'Digital_Sleep_Lab_01-25-2020_4_5310117742903296.mp4': ['eat a tates,\n\nCat) Avge\n\n192°',
#   'Most Pickups Total Pickups\nNednesday: 180 684',
#   'Socal Nelworng bk etertyeme nt 9 Bros cteeity\n12h 20m Tih 26m in 28m\n\nTotal Screen Time 38h 21m'],
#  'Digital_Sleep_Lab_01-25-2020_4_5855160836816896.mp4': ['aye Cat ret\n\nTeta, 25 20,\n\n163°',
#   'all ww aie\n\nst Pickup Total Pickups\n00:04 121',
#   'Soria Networking Productivity Eniertanment\n4b 19m 9m 6m\n\nVodated today atl? 26'],
#  'Digital_Sleep_Lab_01-27-2020_4_5702815863799808.mp4': ['MTEC ately\n\nVals A-etoge\n\n86°',
#   'Most Pickups Total Pickups\nTuesday: 38 38',
#   'C191 Neiwor hung Gores Entertornment\nh 21m Ih im <0m\n\notal Screen Time én 57m'],
#  'Digital_Sleep_Lab_01-29-2020_4_5540104987213824.mp4': ['wt Caters\n\nOo ty Aewt soe\n\n290°',
#   'Most Pickups Total Pickups\nTuesday: 187 338',
#   'Soe cel net er cata écnusement Gaines\nBu, Agm 7u, 31m Su S2m\n\nTotale schermtyd 42u,54m'],
#  'Digital_Sleep_Lab_09-19-2019_4_5561239304929280.mp4': ['ROTH AT.CHAS\n\n823°',
#   'Most Pickups Total Pickups\nSaturday: 88 486',
#   'ee CleAly\nwin\ntease Meee te\n\nne\n\n  \n\n \n\nmn ae'],
#  'Digital_Sleep_Lab_09-19-2019_4_6564569099534336.mp4': ['HOTEL AT IONS\n\n75°',
#   'Most Pickups Total Pickups\nThursday: 60 112',
#   'octal Networking Pzecuctivity — Entértaiamen:\n6m 12m 8in\n\nNockly Total 2h 15m'],
#  'Digital_Sleep_Lab_09-20-2019_4_5028874283384832.mp4': ['HOTHEICATIONS\n\n11°',
#   't Pickup Total Pickups\n5:17 54',
#   'Productivity Secial Networking — Entertainment\nIh 27m 31m 1m'],
#  'Digital_Sleep_Lab_09-22-2019_4_6402762816880640.mp4': ['TIT AT TNS\n\n9°',
#   'First Pickup Total Pickups\n407:45 28',
#   'Productivity Sccial Neteorking — Entertainment\n32m 1§m 2m'],
#  'Digital_Sleep_Lab_09-23-2019_4_5553477963481088.mp4': ['HOD al ous\n\n9°',
#   'First Pickup Total Pickups\n4 06:05 47',
#   'Social Networking Productivity Creativity\n32m 25m 9m'],
#  'Digital_Sleep_Lab_09-25-2019_4_6321273999720448.mp4': ['HOTS CAT OG\n\n6°',
#   'First Pickup Total Pickups\n400:25 8',
#   'Secu! Networking Produc tnity Omer\nSn 13m In 65m In 6m\n\nWeekly Total 13h $8m'],
#  'Digital_Sleep_Lab_09-26-2019_4_5051152245194752.mp4': ['to EARLY\n\n3.569°\n\nAe',
#   'Mas veces consultado Consultas en total\njueves: 265 1.278',
#   '7. ae OE\n\n \n\nROOESSICICS TOULEIRO Sey eetrete mm carp\n21h 20mn In 38mn in 36mm\n\nTotal semanal 33m 47min'],
#  'Digital_Sleep_Lab_09-27-2019_4_5657390939111424.mp4': ['POOTITALIONS\n\n91°',
#   'Most Pickups Total Pickups\nSunday: 120 561',
#   'SOC a" Neteroriing PO sut tidy Eoterty cm est\n4n 50m in 3m aim\n\nVeecxly Total 10h 22m'],
#  'Digital_Sleep_Lab_09-27-2019_4_5820415616745472.mp4': ['3.623° ,',
#   'Mas veces consultado Consultas en total\njueves: 265 1.268',
#   'Redes socu’es  Entreten ments Produttividad\n22h 62min Ih 38min Mn 2min\n\nTotal semanoal 34n S9min'],
#  'Digital_Sleep_Lab_09-29-2019_4_5175097988481024.mp4': ['',
#   'Most Pickups Total Pickups\nSunday: 95 486',
#   'Social Meteor tiny Preatuctiaty Caterta ament\n3b 36m tn 32m 3am\n\nWeekly Total Sn 3m |'],
#  'Digital_Sleep_Lab_09-29-2019_4_5578887157776384.mp4': ['3.581°',
#   'Mas veces consultado Consultas en total\njueves: 265 1.264',
#   'Redes socnles Fatretenmnments  Froguctinicad\n26n 39mun Ih 59min 1h 16min\n\nTotal semanal 40h Smin'],
#  'Digital_Sleep_Lab_09-30-2019_4_5878729427910656.mp4': ['Pert A neh\n\n4.034° ,',
#   'Mas veces consultado Consultas en total\njueves: 265 1.348',
#   'Redes socules — Leteeteaivietto. | Ceeatnidiad\n25h Simn 2n VStran 1h 18 mun\n\nTotal semongl A0h 17min'],
#  'Digital_Sleep_Lab_10-01-2019_4_5224234125623296.mp4': ['70°',
#   'Most Pickups Total Pickups\nSunday: 95 496',
#   'SOC131 Networking Procectuaty Health & Fitness\n2h Sim 2h 10m 35m\n\nWeekly Total on Bm'],
#  'Digital_Sleep_Lab_10-01-2019_4_5244244814462976.mp4': ['3.990° .',
#   'Mas veces consultado Consultas en total\nmartes: 275 1.394',
#   'Redes socuies sntretes. Meno Pred ctwidod\n25h 27mn 2m 18m th 21min\n\nTotal semangl 39h AIM'],
#  'Digital_Sleep_Lab_10-02-2019_4_5924249806569472.mp4': ['3.890° ,,',
#   'Mas veces consultado Consultas en total\nmartes: 275 1.296',
#   'Redes socules = Entrcterumiento = Productividad\n26h 27min 2h 15min th 18min\n\nTotal semanal 38h 45min'],
#  'Digital_Sleep_Lab_10-03-2019_4_4568678536839168.mp4': ['OTE EM ONS\n\n1.387°',
#   'Most Pickups Total Pickups\nThursday: 257 1.362',
#   'Socal Nemwora ng MOC attity Otrer\n1$n 39m 3n §2m 2n 48m\n\nWeekly Total 35h aGm'],
#  'Digital_Sleep_Lab_10-04-2019_4_4854233094946816.mp4': ['HOT EAT CNS\n\n1.246°',
#   'Most Pickups Total Pickups\nThursday: 257 1.398',
#   'Social Networking Otner Produciiwity\n17h 6m 2h 58m 2h 30m\n\nWeekly Total I3Bh 12M'],
#  'Digital_Sleep_Lab_10-06-2019_4_5227228791570432.mp4': ['5 WHCA ONS\n\n1.249° _',
#   'Most Pickups Total Pickups\nThursday: 257 1.276',
#   'Socal Networking Otner Productivity\n15h 44n 3h 14m 3h 3m\n\nWeekly Total 33h 11m'],
#  'Digital_Sleep_Lab_10-06-2019_4_6400422596575232.mp4': ['re\n\nCas’) Aveeage\n\n45°',
#   'Most Pickups Total Pickups\nSunday: 64 64',
#   'Tap ar Cece em Foe'],
#  'Digital_Sleep_Lab_10-13-2019_4_5869933905313792.mp4': ['',
#   'Most Pickups Total Pickups\nSaturday: 124 495',
#   'seeder oe\n\n \n\nove,\nKile\n\n \n\n4\n\n \n\nSo them'],
#  'Digital_Sleep_Lab_10-13-2019_4_6481110737879040.mp4': ['sete Tate,\n\nDa ty deca ge\n\n995°',
#   'Most Pickups Total Pickups\nFriday: 175 620',
#   'DATS LNUIAIIY  CEne Ane Pru\n\n10h Sm Ih 12m 48m\n\nTotal Screen Time 16h 4m'],
#  'Digital_Sleep_Lab_11-03-2019_4_6356206378024960.mp4': ['Gemiddelde per dag\n\n85°\n\n€',
#   'Vaakst opgepakt _Totaal aantal keer opgepakt\nvrijdag: 367 1.244',
#   'Soc ul neiworking Prec ac teatedt Amusement\nWu, 43m 2u,45m Vu, $7m\n\nTotale schermtyd 38 u, 51m'],
#  'Digital_Sleep_Lab_11-05-2019_4_6077309077946368.mp4': ['Davy Average\n\n138° °',
#   'Most Pickups Total Pickups\nNednesday: 180 684',
#   'Seesltetvoraing «Other = Productivity\nSham 32m 31m\n\nTotal Screen Time 8h 53m'],
#  'Digital_Sleep_Lab_11-09-2019_4_5554984750415872.mp4': ['Mer ees\n\nCore 9\nSodio percag\n\n91°',
#   '/Jaakst opgepakt Totaal aantal keer opgepakt\nJonderdag: 111 449',
#   'Socal networking Arrusemrent Ancers\n8u, 31m §5u,47m 2u, 27m\n\nTotale «charmtsd 924, 29M'],
#  'Digital_Sleep_Lab_11-14-2019_4_6209347177152512.mp4': ['hotpe aah.\n\nOvty aarage\n\n46°',
#   'Most Pickups Total Pickups\nFriday: 1 1',
#   '“8 teat Lee\nOe "oe\n\nwen\nshan\n\ntite now tere'],
#  'Digital_Sleep_Lab_11-15-2019_4_4984582424756224.mp4': ['thw, A.wesse\n\n46°',
#   'Most Pickups Total Pickups\nSaturday: 1 1',
#   '“¢ te a trey 4 vote\n\nts\n\n   \n\nwevat\n\n \n\nwee\n\niva Sewer love'],
#  'Digital_Sleep_Lab_11-15-2019_4_5785748444282880.mp4': ['are Pate ns\n\n‘Wtae MWe Meee ba',
#   'First Pickup Total Pickups\n400:52 32',
#   'Social Networking Productivity Education\n21m 7m 2m\n\nLindated tacdayv rat 11.%46'],
#  'Digital_Sleep_Lab_11-16-2019_4_5183000652808192.mp4': ["Kats AAS\n\nGotmdde'de per dag\n\n242°",
#   'Vaakst opgepakt Totaal aantal keer opgepakt\nwoensdag: 179 824',
#   'Soe cel net er cata écnusement Gaines\nBu, Agm 7u, 31m Su S2m\n\nTotale schermtyd 42u,54m'],
#  'Digital_Sleep_Lab_11-17-2019_4_5710230369861632.mp4': ['AML ERE\n\nWaretoeg 1\n\n65°',
#   'Eerste keer opgepakt Totaal aantal keer opgepakt\n4 00:01 50',
#   'Soeur retsoraing Games Lezen ern naslg\n3u. 32m 31m 7m\n\nUigearerkt vardrag 19 23'],
#  'Digital_Sleep_Lab_11-17-2019_4_6085186249293824.mp4': ['OE Ne OE\n\nGera) Selsey per du\n\n289°',
#   'Vaakst opgepakt Totaal aantal keer opgepakt\ndonderdag: 242 1.176',
#   'SCV te tnOrbrwy Amusement Productunnt\n9u. 48m Bu 22m Yuliya\n\nTotale schermtyd 274, 20m'],
#  'Digital_Sleep_Lab_11-18-2019_4_5198243693068288.mp4': ['wipe ates\n\nsat hee ae',
#   'Most Pickups Total Pickups\nsunday: 104 108',
#   'DOC I Networtung Provactay Read.ng & Reference\n2h lim 16m 12m\n\nTotal Screen Time 3h 20m'],
#  'Digital_Sleep_Lab_11-21-2019_4_5041346893578240.mp4': ['ee Tay\n\nCoty aacta\n\n169°',
#   'Most Pickups Total Pickups\nTuesday: 116 261',
#   'SocwI Networking = cate:tramen: — Producinity\n3h 28m Mh aim 56m\n\nTotal Screen Time 17h 5m'],
#  'Digital_Sleep_Lab_11-21-2019_4_5254030385741824.mp4': ['ee Oe\n\nGera tele pet di\n\n203° ‘',
#   'Vaakst opgepakt Totaal aantal keer\nwoensdag: 212. 528',
#   'AnH eke PME EEG es\n\nSu. 51m Vu, 59m Vu, 42m\n\nTotale schermtyd 13.u, 3m'],
#  'Digital_Sleep_Lab_11-21-2019_4_5786423190355968.mp4': ['MELO batts\n\nALLS Ping nte\n\n168°',
#   'Vaakst opgepakt _—‘Totaal aantal keer opgepakt\nwoensdag: 159 566',
#   '8u. 36m\n\nTotale schermtyd 21u, 44m'],
#  'Digital_Sleep_Lab_11-22-2019_2_Battery section video_5087127956619264.mp4': ['eat tw tat es\n\nCrty Ace e\n\n290°',
#   'Most Pickups Total Pickups\nNednesday: 271 856',
#   'Sool sero rg Gores Enter taummen:\n13h $7m In 25m th 13m\n\nTotal Screen Time 26n 29m'],
#  'Digital_Sleep_Lab_11-22-2019_4_6426243193372672.mp4': ['NA ae\n\nGemeidelde per das\n\n271°',
#   'Vaakst opgepakt Totaal aantal keer op\nwoensdag: 212 781',
#   'SOM OLA CNT AM soment Precuctnatent\nBulim Jum Vy. 54m\n\nTotale scheemtid 18u. 22m'],
#  'Digital_Sleep_Lab_11-24-2019_4_5799868350595072.mp4': ['NEE NOE AE\n\nDaily Average\n\nRz7°',
#   'Most Pickups Total Pickups\nSaturday: 126 550',
#   'Sora’ Petagiery Eniertannent Gomes\n14n 39m 2h 1S in 29m\n\nTotal Sercen Time 27h 11m'],
#  'Digital_Sleep_Lab_11-24-2019_4_5907383562272768.mp4': ['Mere tates\n\nDab ty Average\n\n283°',
#   'Most Pickups Total Pickups\nSaturday: 207 1.030',
#   'Soeur Netnorersy Encestaament Produc traty\n17 30m 7h 69m 2h 8m\n\nTotal Screen Time 40n 39m'],
#  'Digital_Sleep_Lab_11-25-2019_4_5236865548943360.mp4': ['ipa Cae,\n\nOs y Aveeage\n\n7°',
#   'Most Pickups Total Pickups\nTuesday: 1 1',
#   'Enterta ccrest Sociol Networking Croatmty\nin 41m 22m Sm\n\nTotal Screen Time 5m'],
#  'Digital_Sleep_Lab_11-25-2019_4_6388877078560768.mp4': ['PATE RATIO >\n\nDaily Average\n\n92°',
#   'Most Pickups Total Pickups\nTuesday: 15 15',
#   'whrettra get DERI O A NQ eT Rb ty\nson Sim Son\n\nToral Screen Tune In 46ra'],
#  'Digital_Sleep_Lab_11-26-2019_4_5883411403636736.mp4': ['tet ares.\n\nOty Ave-age\n\n41°',
#   'Most Pickups Total Pickups\nTuesday: 1 2',
#   'Ertenascrent Sox’ Networing Creatunty\n$n $3m in $1m 1$-n\n\nTotal Screen Time am'],
#  'Digital_Sleep_Lab_11-27-2019_4_5319684161798144.mp4': ['eettasla ong\n\nCony Average\n\n45°',
#   'Most Pickups Total Pickups\nTuesday: 1 2',
#   'iMertanment Social Networking Creativity\nan 7m 3h 10m 36m\n\nTotal Screen Time 12m'],
#  'Digital_Sleep_Lab_11-27-2019_4_6415398937821184.mp4': ['HOTS AICS\n\nOnily Average\n\nQa°',
#   'Most Pickups Total Pickups\nTuesday: 109 194',
#   'Se rul Metaoatg Enterta nnen: Createvity\nSh 2an 2h 59m 44m\n\nTotal Screen Time 13h 20m'],
#  'Digital_Sleep_Lab_11-28-2019_4_4630350400061440.mp4': ['te ba ey\n\nOns, Auta\n\n17°',
#   'Most Pickups Total Pickups\nTuesday: 61 179',
#   'Oc Networkanng Vow ecte ty tnterty arent\nGh 25m 3am sim\n\nTotal Sereen Time 12h 51m'],
#  'Digital_Sleep_Lab_11-28-2019_4_5653674106290176.mp4': ['ates\n\nOsdr Average\n\n0°',
#   'Most Pickups Total Pickups\nTuesday: 1 2',
#   'Soe! Networking Eetetanren: Brod xtanty\n6 19en 1h 58m tn 22m\n\nTotal Screen Time 33m'],
#  'Digital_Sleep_Lab_11-29-2019_4_6275219795214336.mp4': ['toot at\n\n \n\nOst, Aeros\n\n85°',
#   'Most Pickups Total Pickups\n\nThursday: 90 350',
#   'tomy,\nVA\n\n  \n\nPac ar Crema Fon Ae. 4m'],
#  'Digital_Sleep_Lab_11-30-2019_4_5019348339523584.mp4': ['Me ett\n\nlar te eee Ce chars\n\n251° r',
#   'Jaakst opgepakt Totaal aantal keer opgepakt\nsrijdag: 199 435',
#   'rocuctvitert = Socuinetucring = Amusement\n>u, 2m 4u,10m 3u,43m\n\nlotale schermtyd 10 u, 44m'],
#  'Digital_Sleep_Lab_11-30-2019_4_5244964380868608.mp4': ['tate ae\n\n \n\nfa ty Aweage\n\n95°',
#   'Most Pickups Tota! Pickups\nSaturday: 110 449',
#   'KC ee ort e,\nM3 ae\n\n \n\nane Nhe eee\n\nan\n\n \n\neon Clipe late'],
#  'Digital_Sleep_Lab_11-30-2019_4_5771441472012288.mp4': ['seote at ree\n\nDe dere',
#   'Most Pickups Total Pickups\nFriday: 114 493',
#   'Ocul Networsng  Enterianment Productivity\n59m 6h 12m In 33m\n\notal Screen Time 21h 29m'],
#  'Digital_Sleep_Lab_12-01-2019_4_4637619699318784.mp4': ['fe at\n\nDuby Aes\n\nRn?',
#   'Most Pickups Total Pickups\nFriday: 114 588',
#   'Entertanment Social Networking Productivity\n12h §m 7h 43m 2h 9en\n\nTotal Screen Time 29h 41m'],
#  'Digital_Sleep_Lab_12-01-2019_4_6158145160740864.mp4': ['MALO Solfo\n\nGe middie de pe! cag\n\n240° r',
#   'aakst opgepakt Totaal aantal keer opgepakt\nrit}dag: 199 507',
#   'Productentet Soc al acteo sanz | Amusement\n6u, 44m 4u, 49m 3u,4ém\n\nTotale schermtyd 12u, 43m'],
#  'Digital_Sleep_Lab_12-02-2019_4_5616895126929408.mp4': ['Vuh Ose\n\nCov.cce\'se pe" Org\n\n16°',
#   "Vaakst opgepakt Totaal aantal keer opgepak'\ndinsdag: 13 13",
#   'Procuctrvitent Social networking Anders\n5m 3m im\n\nTotale schermtyud 16m'],
#  'Digital_Sleep_Lab_12-02-2019_4_5781757245259776.mp4': ['OD ee AS\n\nLast Mieck $ Average\n\n114°',
#   'Most Pickups Total Pickups\nFriday: 132 702',
#   'Aue\nmA\n\n \n\nPe date ty\n\ntm tty\n\n \n\nlute Kt tne\n\n“Em WA me ES 4S\n\n \n\n*\n\non\n\nVWGdy Dyers'],
#  'Digital_Sleep_Lab_12-02-2019_4_5814793462611968.mp4': ['oe few atane\n\nMe. Aw age',
#   'Most Pickups Total Pickups\nTuesday: 14 14',
#   'Social Networking = Productu.ty Entertainment\n12m 3m 3m\n\nTotal Screen Time 23m'],
#  'Digital_Sleep_Lab_12-03-2019_4_4943800804311040.mp4': ['sagt ats\n\nUw y srctae',
#   'Most Pickups Total Pickups\nSunday: 140 290',
#   'Secu Sera ey Otree Procucinuty\n250 men 29 ran 19mA\n\nTotal Screen Tine §h 60 min'],
#  'Digital_Sleep_Lab_12-03-2019_4_5827146728079360.mp4': ['mee at tee\n\nOr. Aww oye\n\n86°',
#   'Most Pickups Total Pickups\nTuesday: 75 110',
#   'Se ola\nhim\nCen trey A bee\nan\n\n     \n\n \n\ntwa Serre t\n\n \n\nWn ale'],
#  'Digital_Sleep_Lab_12-03-2019_4_5899438342537216.mp4': ['eS\n\nen Aer ae\n\n77°',
#   'Most Pickups Total Pickups\nTuesday: 204 216',
#   'Socal Networking Tatertyen ect Other\nth 37m 22m\n\nTotal Screen Tune 3h Jem'],
#  'Digital_Sleep_Lab_12-03-2019_4_6331632680697856.mp4': ['OTR a OS\n\nDuly Average\n\n73°',
#   'Most Pickups Total Pickups\nTuesday: 102 117',
#   'ery sobre, A ee we\n\n \n\n \n\nled Stewie'],
#  'Digital_Sleep_Lab_12-03-2019_4_6688059098136576.mp4': ["2EON is\n\nSem :dde'ce Cer dag\n\n169° 0:",
#   'Vaakst opgepakt Totaal aantal keer opgepakt\ndinsdag: 216 242',
#   'roducimnte.t Sec averetaakeg  Amarcrent\nvim som 38m\n\nfotale schermtyd éu.iim'],
#  'Digital_Sleep_Lab_12-04-2019_4_6343848473657344.mp4': ['tt ate\n\nQu sy duweaie\n\n87°',
#   'Most Pickups Total Pickups\nWednesday: 113 227',
#   '+ ton\n\n \n\nwan Tam\nWer\n\nwe\n\nter Strews lew foes'],
#  'Digital_Sleep_Lab_12-05-2019_4_5112395450548224.mp4': ['faa oy\n\nCat, Average\n\n195° _',
#   'Most Pickups Total Pickups\nThursday: 151 452',
#   'Atertgmment Seca’ het orbiag — Precucinety\nIn SOm én 34m 1h Im\n\nfotal Screen Time 15n 3m'],
#  'Digital_Sleep_Lab_12-05-2019_4_5644090658521088.mp4': ['',
#   'Most Pickups Total Pickups\nWednesday: 145 42)',
#   'Ocul Networking Entertainment = Produc trvity\nnh 46m 3h 29m 2h 47m\n\notal Screen Time 15h 52m'],
#  'Digital_Sleep_Lab_12-06-2019_4_4597500342697984.mp4': ['et at\n\nDit) emer\n\n81°',
#   'Most Pickups Total Pickups\nWednesday: 145 488',
#   'POC Networking Entertanment Productivity\nph AO 3h 31m 3n 17m\n\nfotal Screen Time 19h 15m'],
#  'Digital_Sleep_Lab_12-09-2019_4_5184539291287552.mp4': ['BOE Cat es\n\nOty Ascerge\n\n24°',
#   'Most Pickups Total Pickups\nTuesday: 19 19',
#   'Sociul Networking Productivity Other\n8m Sm Sm\n\nTotal Screen Time 29m'],
#  'Digital_Sleep_Lab_12-09-2019_4_5224738239021056.mp4': ['Tert@e a ey\n\nOo67 Average',
#   'Most Pickups Total Pickups\nTuesday: 11 11',
#   'Socul Networking Pron atteaty Enterta rent\n49m 18m 14m\n\nTotal Screen Time ih 2m'],
#  'Digital_Sleep_Lab_12-09-2019_4_5367900571959296.mp4': ['AG\n\nCome sete von\n\n162°',
#   'Vaakst opgepakt Totaal aantal keer opgepakt\nvrijdag: 151 772',
#   'Sec artaonuing Ar sement Onderngs\n19u 59m 6u.19Mm du, jm\n\nTotale schermtyd 64u,33m'],
#  'Digital_Sleep_Lab_12-09-2019_4_6517361125883904.mp4': ['',
#   'VV\n\nFirst Pickup\n4 05:34\n\nVu\n\nV<é\n\nTotal Pickups\n32',
#   'Entertanrent Som Netaccatq  Freduct any\n59m 3im im\n\nUentites tender ot 1S 06'],
#  'Digital_Sleep_Lab_12-10-2019_4_5027542533144576.mp4': ['Mer wg\n\nGeese OC" ¢\n\n64°',
#   'tvd v ve ws v <\n\nVaakst opgepakt Totaal aantal keer\ndinsdag: 76 87',
#   'Socal ne: or king Caceness Amusemeon,\n2u.l2m SIm 2m\n\nTotale scheemtyd au, 23m'],
#  'Digital_Sleep_Lab_12-10-2019_4_6376722354667520.mp4': ['Telstra tie\n\nToday, December\n\nan?',
#   'First Pickup Total Pickups\n40:20 18',
#   'Sot Netnors aq Productaity Reading & Reference\n23m 12m 7m\n\nUGIaIEd toc ay B14'],
#  'Digital_Sleep_Lab_12-11-2019_4_6694086078103552.mp4': ['Het at wd\n\nToda, 11 Cece tee\n\n46°',
#   '-irst Pickup Total Pickups\n4 00:01 85',
#   'Entertainment Social Netucraing = Productivity\n51m 12m 12m\n\nUoedosed today at 15 13'],
#  'Digital_Sleep_Lab_12-13-2019_4_6059879328907264.mp4': ['Nee ates\n\nOw, Acers or\n\n142°',
#   'Most Pickups Total Pickups\nWednesday: 90 291',
#   'Social Networking Other Productivity\n14h 2m 4h 40m th im\n\nTotal Screen Time Wh IM']}
